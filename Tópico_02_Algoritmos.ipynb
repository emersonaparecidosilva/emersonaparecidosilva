# %% [markdown]
# <a href="https://colab.research.google.com/github/emersonaparecidosilva/emersonaparecidosilva/blob/main/T%C3%B3pico_02_Algoritmos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Escreva uma expressão para determinar se uma pessoa deve ou não pagar imposto.
# Considere que pagam imposto pessoas cujo salário é maior que 1200.00.
#
#    Para teste, considere os salários 1300.00, 1000.00 e 1200.00.

# %%
salario = 1000
pagaImposto =  salario >= 1200
print(pagaImposto)
# Out:
# False

# %%
salario = 1300
pagaImposto =  salario >= 1200
print(pagaImposto)
# Out:
# True

# %%
salario = 1200
pagaImposto =  salario >= 1200
print(pagaImposto)
# Out:
# True

# %% [markdown]
# 2. Calcule o resultado da expressão
#
#       A > B and C or D
#
#    utilizando os valores da tabela a seguir.
#
#
#   ![F1.png](data:image/png;base64,...)

# %%
1 > 2 and True or False
# Out:
# False

# %%
10 > 3 and False or False
# Out:
# False

# %%
5 > 1 and True or True
# Out:
# True

# %% [markdown]
# 3. Escreva uma expressão que será utilizada para decidir se um aluno foi ou não aprovado. Para ser aprovado, a média das notas do aluno devem ser maiores ou iguais a 7.
#    Considere que o aluno cursa apenas três matérias, e que a nota de cada uma está armazenada nas seguintes variáveis: nota1, nota2 e nota3.

# %%
nota1 = float(input("Digite a Primeira Nota: "))
nota2 = float(input("Digite a Segunda Nota: "))
nota3 = float(input("Digite a Terceira Nota: "))
media = (nota1+nota2+nota3)/3
if media >= 7:
  print("Aprovado com a média de %2.2f" % media)
else:
  print("Reprovado com a média de %2.2f" % media)
# Out:
# Digite a Primeira Nota: 10
# Digite a Segunda Nota: 5
# Digite a Terceira Nota: 1
# Reprovado com a média de 5.33

# %% [markdown]
# 4. Qual o valor da expressão: 2 + 3 * 4 - 5. Tente resolver antes de montar o código.

# %%
 expressao = 2 + 3 * 4 - 5
 print(expressao)
# Out:
# 9

# %% [markdown]
# 5. Qual o valor da expressão: 2 + 3 * (4 - 5). Tente resolver antes de montar o código.

# %%
expressao =2+3*(4-5)
print(expressao)
# Out:
# -1

# %% [markdown]
# 6. Faça um programa que peça dois números inteiros. Imprima a soma desses dois números na tela.

# %%
numero1 = int(input("Digite o 1º Número: "))
numero2 = int(input("Digite o 2º Número: "))
print(numero1+numero2)
# Out:
# Digite o 1º Número: 5
# Digite o 2º Número: 10
# 15

# %% [markdown]
# 7. Escreva um programa que leia um valor em metros e o exiba convertido em milímetros.

# %%
valorMetro = float(input("Digite Qual a Metragem: "))
valorMm = (valorMetro*1000)
print("Em metros, você digitou %6.2f que equivale a %d em Milimetros" %(valorMetro,valorMm))
# Out:
# Digite Qual a Metragem: 10
# Em metros, você digitou  10.00 que equivale a 10000 em Milimetros

# %% [markdown]
# 8. Escreva um programa que leia a quantidade de dias, horas, minutos e segundos do usuário. Calcule o total em segundos.

# %%
dias = int(input("Digite o número de Dias "))
horas = int(input("Digite o número de horas "))
minutos = int(input("Digite o número de minutos "))
segundos = int(input("Digite o número de segundos "))

diasemsegundos = dias*86400
horasemsegundos = horas*3600
minutosemsegundos = minutos*60

total = (diasemsegundos+horasemsegundos+minutosemsegundos)
print("A soma de %d Dia(s), %d Hora(s), %d Minuto(s), %d Segundo(s) é igual a %d Segundos" %(dias, horas, minutos, segundos, total))
# Out:
# Digite o número de Dias 1
# Digite o número de horas 1
# Digite o número de minutos 1
# Digite o número de segundos 1
# A soma de 1 Dias, 1 Horas, 1 Minutos, 1 Segundos é igual a 90060 Segundos

# %% [markdown]
# 9. Faça um programa que calcule o aumento de um salário. Ele deve solicitar o valor do salário e a porcentagem do aumento. Exiba o valor do aumento e do novo salário.

# %%
salário = float(input("Qual o salário atual do funcionário: "))
porcentagemAumento = float(input("Qual o percentual de aumento: "))
fatorAumento = 1+porcentagemAumento
novoSalario = salário*fatorAumento
print("O Salário anterior: R$%6.2f e o Salário com aumento: R$%6.2f" % (salário,novoSalario))
# Out:
# Qual o salário atual do funcionário: 4000
# Qual o percentual de aumento: 10
# O Salário anterior: R$4000.00 e o Salário com aumento: R$44000.00

# %% [markdown]
# 10. Faça um programa que solicite o preço de uma mercadoria e o percentual de desconto. Exiba o valor do desconto e o preço a pagar.

# %%
valorCheioProduto = float(input("Qual o valor do produto: "))
descontoAplicado = float(input("Qual o valor do desconto aplicado: "))
valorDesconto = valorCheioProduto/descontoAplicado
print("O valor do Desconto é R$%5.2f"% valorDesconto)
valorFinal = valorCheioProduto - valorDesconto
print("O valor final é R$%5.2f"% valorFinal)
# Out:
# Qual o valor do produto: 100
# Qual o valor do desconto aplicado: 10
# O valor do Desconto é R$10.00
# O valor final é R$90.00

# %% [markdown]
# 11. Escreva um programa que calcule o tempo de uma viagem de carro. Pergunte a distância a percorrer e a velocidade média esperada para a viagem.

# %%
distancia = float(input("Qual a distância: "))
velocidadeMediaHora = float(input("Qual a média de sua velocidade por hora: "))
tempoViagem = distancia/velocidadeMediaHora
print("O tempo de viagem é %2.2f horas"% tempoViagem)
# Out:
# Qual a distância: 50
# Qual a média de sua velocidade por hora: 100
# O tempo de viagem é 0.50 horas

# %% [markdown]
# 12. Escreva um programa que converta uma temperatura digitada em °C em °F. A fórmula para essa conversão é:
#
#     F = (9 * C)/5 + 32

# %%
temperaturaCelsius =  float(input("Qual a temperatura em graus Celsius: "))
f = (9 * temperaturaCelsius)/5 + 32
print("%2.2f em ºC equivale a %2.2f em ºF" % (temperaturaCelsius,f))
# Out:
# Qual a temperatura em graus Celsius: 32
# 32.00 em ºC equivale a 89.60 em ºF

# %% [markdown]
# 13. Escreva um programa que pergunte a quantidade de km percorridos por um carro alugado pelo usuário, assim como a quantidade de dias pelos quais o carro foi alugado. Calcule o preço a pagar, sabendo que o carro custa 60.00 por dia e 0.15 por km rodado.

# %%
kmsRodados =  float(input("Quantos KMs foram percorridos: "))
diasAlugado = int(input("Esse carro foi alugado por Quantos dias? "))

baseAluguel = 60
baseKM = 0.15
valorFinal = baseAluguel*diasAlugado + baseKM*kmsRodados
# print("Valor Aluguel")
# print(baseAluguel*diasAlugado)

# print("Valor KM")
# print(baseKM*kmsRodados)

print(valorFinal)
# Out:
# Quantos KMs foram percorridos: 450
# Esse carro foi alugado por Quantos dias? 7
# Valor Aluguel
# 420
# Valor KM
# 67.5
# 487.5

# %% [markdown]
# 14. Escreva um programa para calcular a redução do tempo de vida de um fumante. Pergunte a quantidade de cigarros fumados por dia e quantos anos ele já fumou. Considere que um fumante perde 10 minutos de vida a cada cigarro, calcule quantos dias de vida um fumante perderá. Exiba o total em dias.

# %%
cigarrosDia = float(input("Quantos Cigarros por dia você fuma?: "))
anosNaFumaca = int(input("Há quantos Anos você fuma?: "))

totalMinutosDias = (cigarrosDia*365) * 10
totalDias = totalMinutosDias / 1440
print(totalDias)
# Out:
# Quantos Cigarros por dia você fuma?: 5
# Há quantos Anos você fuma?: 1
# 12.5
